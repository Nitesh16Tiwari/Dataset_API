# %% [markdown]
# # Top Rated Movies Dataset

# %% [markdown]
# ### Let's take API From https://www.themoviedb.org/

# %% [markdown]
# ### Let's import Data

# %% [markdown]
# * So i have taken a API URL and converted into .Json file.

# %%
import pandas as pd

# %%
# !pip install requests

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIzZWMwNDM1YWViZWEzOTVkZDc3NDYzMmQ1NjQ1Yjc2ZSIsInN1YiI6IjY1NzcwNjI3NGJmYTU0MDBlMTU1Y2YxNyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.4ainz3sT-H_-0IibAa6JjUYulr9CnosTwQa_QAcQNbg"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/tmU7GeKVybMWFButWEGl2M4GeiP.jpg","genre_ids":[18,80],"id":238,"original_language":"en","original_title":"The Godfather","overview":"Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.","popularity":203.45,"poster_path":"/3bhkrj58Vtu7enYsRolD1fZdja1.jpg","release_date":"1972-03-14","title":"The Godfather","video":false,"vote_average":8.709,"vote_count":19084},{"adult":false,"backdrop_path":"/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where h
# ...

# %% [markdown]
# * Here i have converted movie data in .json format

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 203.45,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.709,
#    'vote_count': 19084},
#   {'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
# ...

# %% [markdown]
# #### Let's make a list of this file as it is in dictnory format.

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 203.45,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.709,
#   'vote_count': 19084},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %% [markdown]
# #### Now we will make a Dataframe of this data.

# %%
import pandas as pd
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg  [18, 80]  238                en
# 1  False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg  [18, 80]  278                en
#
#              original_title  \
# 0             The Godfather
# 1  The Shawshank Redemption
#
#                                             overview  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...     203.450
# 1  Framed in the 1940s for the double murder of h...     158.633
#
#                         poster_path release_date                     title  \
# 0  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
# 1  /q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg   1994-09-23  The Shawshank Redemption
#
#    video  vote_average  vote_count
# 0  False         8.709       19084
# 1  False         8.706       25083

# %% [markdown]
# #### Let's extract the columns you want

# %%
temp_df= pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
temp_df
# Out:
#         id                                          title  \
# 0      238                                  The Godfather
# 1      278                       The Shawshank Redemption
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4    19404                    Dilwale Dulhania Le Jayenge
# 5      389                                   12 Angry Men
# 6      129                                  Spirited Away
# 7   496243                                       Parasite
# 8      155                                The Dark Knight
# 9      497                                 The Green Mile
# 10  372058                                     Your Name.
# 11     680                                   Pulp Fiction
# 12     122  The Lord of the Rings: The Return of the King
# 13      13                                   Forrest Gump
# 14     429                 The Good, the Bad and the Ugly
# ...

# %% [markdown]
# #### Now we have to start a loop

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# * Here i have created an empty DataFrame

# %%
for i in range(1,452):
    response = requests.get("https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={}".format(i), headers=headers)
    temp_df= pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df=pd.concat([df, temp_df],ignore_index=True)

# %%
df
# Out:
#          id                        title  \
# 0       238                The Godfather
# 1       278     The Shawshank Redemption
# 2       240        The Godfather Part II
# 3       424             Schindler's List
# 4     19404  Dilwale Dulhania Le Jayenge
# ...     ...                          ...
# 8997  12142            Alone in the Dark
# 8998   5491            Battlefield Earth
# 8999  11059            House of the Dead
# 9000  14164         Dragonball Evolution
# 9001  40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# ...

# %% [markdown]
# ### Converting into CSV

# %%
df.to_csv('movies.csv')
